# %% [markdown]
# # Prueba MVP SOAR-AI
#
# Notebook académico para ejecutar el pipeline localmente desde Anaconda/Jupyter.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

PROJECT_ROOT

# %%
from main import ejecutar_pipeline

reportes = ejecutar_pipeline(imprimir=True)
len(reportes)

# %%
reportes[0]

# %% [markdown]
# ## Consulta interactiva al agente SOC
#
# Usa el reporte seleccionado como contexto, pero permite preguntas generales o específicas.

# %%
import importlib
import src.qwen_agent as qwen_agent

importlib.reload(qwen_agent)
from src.qwen_agent import consultar_agente_soc

reporte = reportes[0]
pregunta = input("Pregunta para el agente SOC: ")
respuesta_agente_soc = consultar_agente_soc(reporte, pregunta)
respuesta_agente_soc
